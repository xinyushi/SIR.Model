# %%
import sys
sys.path.append('../sir/')
from sir import *

# %% [markdown]
# ## Continuous

# %%
b=1
k=1/3
time=150
ii=0.01
r=0
q=1

sol1=SIR_continuous(b,k,time,ii,r,q)
plt.plot(sol1.t, sol1.y[0]*1000, c='b',label='s')    # generate the plot
plt.plot(sol1.t, sol1.y[1]*1000, c='g',label='r')
plt.plot(sol1.t, sol1.y[2]*1000, c='r',label='i')


plt.title("Continuous SIR Model(b=1, k=1/3)")
plt.ylabel("y")
plt.xlabel("x")
plt.legend(['s','r','i'])
plt.savefig('C_SIR_1')

# %%
sum(sol1.y[0:2])
# Out:
# array([0.99      , 0.98083572, 0.96397471, 0.93464636, 0.88818204,
#        0.82555509, 0.75965756, 0.71220424, 0.6960798 , 0.71010535,
#        0.74270512, 0.78285315, 0.82209963, 0.85732801, 0.88720095,
#        0.9116621 , 0.93150487, 0.9471923 , 0.95943563, 0.96891467,
#        0.97625127, 0.98187956, 0.98616377, 0.98944263, 0.99196648,
#        0.99388624, 0.99534144, 0.99645527, 0.99730651, 0.99795087,
#        0.99843947, 0.99881431, 0.99909929, 0.99931448, 0.99947819,
#        0.99960386, 0.99969908, 0.9997708 , 0.9998255 , 0.99986766,
#        0.99989955, 0.99992343, 0.99994151, 0.99995566, 0.99996648,
#        0.99997455, 0.99998047, 0.99998496, 0.99998862, 0.99999149,
#        0.99999362, 0.99999512, 0.99999614, 0.99999691, 0.99999765,
#        0.9999983 , 0.99999881, 0.99999916, 0.99999935, 0.99999942,
#        0.99999943, 0.99999946, 0.9999996 , 0.99999976, 0.99999991,
#        1.00000002, 1.00000007, 1.00000007, 1.00000001, 0.99999992,
# ...

# %%
b=5
k=0.2
time=150
ii=0.01

sol1=SIR_continuous(b,k,time,ii)
plt.plot(sol1.t, sol1.y[0]*1000, c='b',label='s')    # generate the plot
plt.plot(sol1.t, sol1.y[1]*1000, c='g',label='r')
plt.plot(sol1.t, sol1.y[2]*1000, c='r',label='i')


plt.title("Continuous SIR Model(b=5, k=0.2)")
plt.ylabel("y")
plt.xlabel("x")
plt.legend(['s','r','i'])
plt.savefig('C_SIR_2')

# %% [markdown]
# ## Discrete

# %%
T=150
N=1000
ii=0.01
b=5
k=0.2
counts=SIR_discrete(N,ii,b,T,k)
plt.plot(range(T+1), counts[0], c='b',label='s')    # generate the plot
plt.plot(range(T+1), counts[1], c='r',label='i')
plt.plot(range(T+1), counts[2], c='g',label='r')


plt.title("Discrete SIR Model (b=5, k=0.2)")
plt.ylabel("y")
plt.xlabel("x")
plt.legend()
plt.savefig('D_SIR_1')

# %%
T=150
N=1000
ii=0.01
b=1
k=1/3
counts=SIR_discrete(N,ii,b,T,k)
plt.plot(range(T+1), counts[0], c='b',label='s')    # generate the plot
plt.plot(range(T+1), counts[1], c='r',label='i')
plt.plot(range(T+1), counts[2], c='g',label='r')


plt.title("Discrete SIR Model (b=1, k=1/3)")
plt.ylabel("y")
plt.xlabel("x")
plt.legend()
plt.savefig('D_SIR_2')

# %%
# Phase diagram for number of infected people at day 30(Continuous)

import numpy as np

b=5
k=0.1
time=150
ii=0.01

sol1=SIR_continuous(b,k,time,ii)

bs = np.arange(1, 11, dtype=np.int64)
ks = np.logspace(-2,0, 10)

cts = np.zeros((len(bs), len(ks)))
for i, b in enumerate(bs):
    for j, k in enumerate(ks):
        cts[i,j] = SIR_continuous(b,k,time,ii).y[2,29]
        
        
plt.figure(figsize=(10,5))
plt.imshow(cts, extent=[np.min(ks), np.max(ks), np.max(bs), np.min(bs)])
plt.colorbar()
plt.title("Phase diagram for number of infected people at day 30(Continuous)")
plt.xscale('log')
plt.xlabel('k')
plt.ylabel('b')

plt.savefig('Phase_Continuous_I')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: aspect is not supported for Axes with xscale=log, yscale=linear
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: aspect is not supported for Axes with xscale=log, yscale=linear
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Phase diagram for number of susceptible people at day 30(Continuous)

import numpy as np

b=5
k=0.1
time=150
ii=0.01

sol1=SIR_continuous(b,k,time,ii)

bs = np.arange(1, 11, dtype=np.int64)
ks = np.logspace(-2,0, 10)

cts = np.zeros((len(bs), len(ks)))
for i, b in enumerate(bs):
    for j, k in enumerate(ks):
        cts[i,j] = SIR_continuous(b,k,time,ii).y[0,29]
        
        
plt.figure(figsize=(10,5))
plt.imshow(cts, extent=[np.min(ks), np.max(ks), np.max(bs), np.min(bs)])
plt.colorbar()
plt.title("Phase diagram for number of susceptible people at day 30(Continuous)")
plt.xscale('log')
plt.xlabel('k')
plt.ylabel('b')

plt.savefig('Phase_Continuous_S')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: aspect is not supported for Axes with xscale=log, yscale=linear

# %%
# Phase diagram for number of recovered people at day 30(Continuous)

import numpy as np

b=5
k=0.1
time=150
ii=0.01

sol1=SIR_continuous(b,k,time,ii)

bs = np.arange(1, 11, dtype=np.int64)
ks = np.logspace(-2,0, 10)

cts = np.zeros((len(bs), len(ks)))
for i, b in enumerate(bs):
    for j, k in enumerate(ks):
        cts[i,j] = SIR_continuous(b,k,time,ii).y[1,29]
        
        
plt.figure(figsize=(10,5))
plt.imshow(cts, extent=[np.min(ks), np.max(ks), np.max(bs), np.min(bs)])
plt.colorbar()
plt.title("Phase diagram for number of recovered people at day 30(Continuous)")
plt.xscale('log')
plt.xlabel('k')
plt.ylabel('b')

plt.savefig('Phase_Continuous_R')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: aspect is not supported for Axes with xscale=log, yscale=linear

# %%
# Phase diagram for number of susceptible people at day 30(Discrete)

import numpy as np

T=150
N=1000
ii=0.01
b=5
k=0.1


bs = np.arange(1, 11, dtype=np.int64)
ks = np.logspace(-2,0, 10)

cts = np.zeros((len(bs), len(ks)))
for i, b in enumerate(bs):
    for j, k in enumerate(ks):
        cts[i,j] = SIR_discrete(N,ii,b,T,k)[0,29]
        
        
plt.figure(figsize=(10,5))
plt.imshow(cts, extent=[np.min(ks), np.max(ks), np.max(bs), np.min(bs)])
plt.colorbar()
plt.title("Phase diagram for number of susceptible people at day 30(Discrete)")
plt.xscale('log')
plt.xlabel('k')
plt.ylabel('b')

plt.savefig('Phase_Discrete_S')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: aspect is not supported for Axes with xscale=log, yscale=linear

# %%
# Phase diagram for number of infected people at day 30(Discrete)

import numpy as np

T=150
N=1000
ii=0.01
b=5
k=0.1


bs = np.arange(1, 11, dtype=np.int64)
ks = np.logspace(-2,0, 10)

cts = np.zeros((len(bs), len(ks)))
for i, b in enumerate(bs):
    for j, k in enumerate(ks):
        cts[i,j] = SIR_discrete(N,ii,b,T,k)[1,29]
        
        
plt.figure(figsize=(10,5))
plt.imshow(cts, extent=[np.min(ks), np.max(ks), np.max(bs), np.min(bs)])
plt.colorbar()
plt.title("Phase diagram for number of infected people at day 30(Discrete)")
plt.xscale('log')
plt.xlabel('k')
plt.ylabel('b')

plt.savefig('Phase_Discrete_I')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: aspect is not supported for Axes with xscale=log, yscale=linear

# %%
# Phase diagram for number of recovered people at day 30(Discrete)

import numpy as np

T=150
N=1000
ii=0.01
b=5
k=0.1


bs = np.arange(1, 11, dtype=np.int64)
ks = np.logspace(-2,0, 10)

cts = np.zeros((len(bs), len(ks)))
for i, b in enumerate(bs):
    for j, k in enumerate(ks):
        cts[i,j] = SIR_discrete(N,ii,b,T,k)[2,29]
        
        
plt.figure(figsize=(10,5))
plt.imshow(cts, extent=[np.min(ks), np.max(ks), np.max(bs), np.min(bs)])
plt.colorbar()
plt.title("Phase diagram for number of recovered people at day 30(Discrete)")
plt.xscale('log')
plt.xlabel('k')
plt.ylabel('b')

plt.savefig('Phase_Discrete_R')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: aspect is not supported for Axes with xscale=log, yscale=linear

# %% [markdown]
# ## Discrete Spatial

# %%
T=150
N=1000
ii=0.01
p=0.05
q=0.008
k=0.2
startpos= [0.5,0.5]
counts=SIR_discrete_spatial(N,ii,p,q,T,k, startpos)
plt.plot(range(T+1), counts[0], c='b',label='s')    # generate the plot
plt.plot(range(T+1), counts[1], c='r',label='i')
plt.plot(range(T+1), counts[2], c='g',label='r')


plt.title("Discrete SIR Model (b=5, k=0.2)")
plt.ylabel("y")
plt.xlabel("x")
plt.legend()
plt.savefig('D_SIR_1')

# %%
T=150
N=1000
ii=0.01
p=0.05
q=0.01
k=0.2
startpos= [0.01,0.01]
counts=SIR_discrete_spatial(N,ii,p,q,T,k, startpos)
plt.plot(range(T+1), counts[0], c='b',label='s')    # generate the plot
plt.plot(range(T+1), counts[1], c='r',label='i')
plt.plot(range(T+1), counts[2], c='g',label='r')


plt.title("Discrete SIR Model (b=5, k=0.2)")
plt.ylabel("y")
plt.xlabel("x")
plt.legend()
plt.savefig('D_SIR_1')

# %%
T=150
N=1000
ii=0.01
p=0.05
q=0.01
k=0.2
#startpos= [0.01,0.01]
counts=SIR_discrete_spatial(N,ii,p,q,T,k,None)
plt.plot(range(T+1), counts[0], c='b',label='s')    # generate the plot
plt.plot(range(T+1), counts[1], c='r',label='i')
plt.plot(range(T+1), counts[2], c='g',label='r')


plt.title("Discrete SIR Model (b=5, k=0.2)")
plt.ylabel("y")
plt.xlabel("x")
plt.legend()
plt.savefig('D_SIR_1')

# %%
pop = [Person([0.5,0.5]) for i in range(1000)]

# %%
T=150
N=1000
ii=0.01
p=0.01
q=0.1
k=0.2
initial_infection = randint(N,size=np.int(N*ii))
for i in initial_infection:
    pop[i].infection()

# %%
count_infected(pop)
# Out:
# 10

# %%
def matrixX(pop,N):
    """
    create matrix X, which stores the position of the population, for KDtree
    """
    X=np.random.rand(N,2)
    for i in range(N):
        X[i]=pop[i].pos
    return X

# %%
X=matrixX(pop,1000)
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
for i in range(N):
    pop[i].newpos(p)
X=matrixX(pop,1000)
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
dpos = np.random.randn(2)
dpos = dpos / np.linalg.norm(dpos)
dpos
# Out:
# array([0.34279241, 0.93941118])

# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
from numpy.random import randint, rand
from scipy.spatial import KDTree
import scipy.linalg as la
import scipy.sparse as sparse

class Person():
    """
    An agent representing a person.
    
    By default, a person is susceptible but not infectious. They can become infectious by exposing with disease method.
    
    Status: 0 = susceptible        1 = infected          2 = removed
    """  
    
    def __init__(self,startpos=None):
        self.status = 0
        if startpos==None:
            self.pos = np.random.rand(2)
        else:
            self.pos = np.array(startpos)

    
    def is_susceptible(self):
        """
        returns true if the person is susceptible
        """
        return self.status==0

    def susceptible(self):
        """
        once the person
        """
        self.status = 0
        
    def is_infected(self):
        """
        returns true if the person is infectious
        """
        return self.status==1

    def infection(self):
        """
        once the person
        """
        self.status=1
      
    def is_removed(self):
        """
        returns true if the person is recovered
        """
        return self.status==2

    def remove(self):
        """
        once the person
        """
        self.status=2
        
    def newpos(self,p):
        """
        new position
        """
        dpos = np.random.randn(2)
        dpos = dpos / np.linalg.norm(dpos)
        newpos = self.pos + dpos * p
        if newpos[0]>=0 and newpos[0]<=1:
            if newpos[1]>=0 and newpos[1]<=1:
                self.pos = newpos


# create matrix A to apply forward difference scheme
def forward_diff_matrix(n):
    data = []
    i = []
    j = []
    for k in range(n - 1):
        i.append(k)
        j.append(k)
        data.append(-1)

        i.append(k)
        j.append(k+1)
        data.append(1)
        
    # incidence matrix of the 1-d mesh
    return sparse.coo_matrix((data, (i,j)), shape=(n-1, n)).tocsr()

def Laplacian(n):
    """
    Create Laplacian on 2-dimensional grid with n*n nodes
    """
    B = forward_diff_matrix(n)
    D = -B.T @ B
    Dx = sparse.kron(sparse.eye(n), D).tocsr()
    Dy = sparse.kron(D, sparse.eye(n)).tocsr()
    return Dx + Dy



def SIR_continuous2(b,p,k,time,ii,startpos,M):
    """
    Simulates continuous SIR model
    ii = initial percentage of infected
    time = Days of simulation
    b = probability that people getting infectious 
    k = probability that people getting recovered
    M = number of grid in each side
    
    returns sol from solve_ivp
    """
    pop = [Person(startpos) for i in range(N)]
    initial_infection = randint(N,size=np.int(N*ii))
    for i in initial_infection:
        pop[i].infection()
    S = np.zeros((M,M))
    I = np.zeros((M,M))
    R = np.zeros((M,M))
    l=1/M
    for i in range(N):
        index_x=np.floor(pop[i].pos/np.array([l,l]))[0]
        index_y=np.floor(pop[i].pos/np.array([l,l]))[1]
        if pop[i].is_susceptible:
            S[int(index_x),int(index_y)]+=1
        if pop[i].is_infected():
            I[int(index_x),int(index_y)]+=1
        if pop[i].is_removed():
            R[int(index_x),int(index_y)]+=1
    Sflat=S.flatten()/N
    Iflat=I.flatten()/N
    Rflat=R.flatten()/N
            
            
    def SIR(t, X):
        z=np.zeros((M*M))
        Y=np.append(np.append(z,z),z)
        Y[0:M*M] = -b * X[0:M*M] * X[2*M*M:] + p * L @ X[0:M*M]
        Y[M*M:2*M*M] = k * X[2*M*M:] + p * L @ X[M*M:2*M*M]
        Y[2*M*M:] = b * X[0:M*M] * X[2*M*M:] - (k * X[2*M*M:]) + p * L @ X[2*M*M:]
        return Y
    t_eval = np.linspace(0, time, 1000)
    y0=np.append(np.append(Sflat,Rflat),Iflat)
    sol1 = solve_ivp(SIR, [0, time], y0, method='RK45', t_eval=t_eval)    # solve the equation
    return sol1


n = 20
h=(1/n)**2
x = np.linspace(0,1,n)
L = Laplacian(n)
L = L.todense()*h
b=0.5
p=0.1
k=1/3
time=150
ii=0.01
startpos=[0.01,0.01]
M=20
N=100

sol1=SIR_continuous2(b,p,k,time,ii,startpos,M)

S=sum(sol1.y[0:M*M])
R=sum(sol1.y[M*M:2*M*M])
I=sum(sol1.y[2*M*M:])

plt.plot(sol1.t, S, c='b',label='s')    # generate the plot
plt.plot(sol1.t, R, c='g',label='r')
plt.plot(sol1.t, I, c='r',label='i')


plt.title("PDE SIR Model(center)")
plt.ylabel("y")
plt.xlabel("x")
plt.legend(['s','r','i'])
plt.savefig('PDE(center)')

# %%
# Phase diagram for number of recovered people at day 30(Continuous)

import numpy as np

n = 20
p=0.1
time=150
ii=0.01
startpos=[0.01,0.01]
M=20
N=100

sol1=SIR_continuous2(b,p,k,time,ii,startpos,M)

bs = np.arange(1, 11, dtype=np.int64)
ks = np.logspace(-2,0, 10)

cts = np.zeros((len(bs), len(ks)))
for i, b in enumerate(bs):
    for j, k in enumerate(ks):
        cts[i,j] = sum(SIR_continuous2(b,p,k,time,ii,startpos,M).y[0:M*M][29])
        
        
        
plt.figure(figsize=(10,5))
plt.imshow(cts, extent=[np.min(ks), np.max(ks), np.max(bs), np.min(bs)])
plt.colorbar()
plt.title("Phase diagram for number of susceptible people at day 30(PDE)")
plt.xscale('log')
plt.xlabel('k')
plt.ylabel('b')

plt.savefig('Phase_PDE_S')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:33: UserWarning: aspect is not supported for Axes with xscale=log, yscale=linear

# %%
n = 20
p=0.1
time=150
ii=0.01
startpos=[0.01,0.01]
M=20
N=100

sol1=SIR_continuous2(b,p,k,time,ii,startpos,M)

bs = np.arange(1, 11, dtype=np.int64)
ks = np.logspace(-2,0, 10)

cts = np.zeros((len(bs), len(ks)))
for i, b in enumerate(bs):
    for j, k in enumerate(ks):
        cts[i,j] = sum(SIR_continuous2(b,p,k,time,ii,startpos,M).y[2*M*M:][29])
        
        
        
plt.figure(figsize=(10,5))
plt.imshow(cts, extent=[np.min(ks), np.max(ks), np.max(bs), np.min(bs)])
plt.colorbar()
plt.title("Phase diagram for number of infected people at day 30(PDE)")
plt.xscale('log')
plt.xlabel('k')
plt.ylabel('b')

plt.savefig('Phase_PDE_I')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: aspect is not supported for Axes with xscale=log, yscale=linear

# %%
n = 20
p=0.1
time=150
ii=0.01
startpos=[0.01,0.01]
M=20
N=100

sol1=SIR_continuous2(b,p,k,time,ii,startpos,M)

bs = np.arange(1, 11, dtype=np.int64)
ks = np.logspace(-2,0, 10)

cts = np.zeros((len(bs), len(ks)))
for i, b in enumerate(bs):
    for j, k in enumerate(ks):
        cts[i,j] = sum(SIR_continuous2(b,p,k,time,ii,startpos,M).y[M*M:2*M*M][29])
        
        
        
plt.figure(figsize=(10,5))
plt.imshow(cts, extent=[np.min(ks), np.max(ks), np.max(bs), np.min(bs)])
plt.colorbar()
plt.title("Phase diagram for number of removed people at day 30(PDE)")
plt.xscale('log')
plt.xlabel('k')
plt.ylabel('b')

plt.savefig('Phase_PDE_R')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: aspect is not supported for Axes with xscale=log, yscale=linear

# %%
ps = np.linspace(0,1, 10)

n = 20
h=(1/n)**2
x = np.linspace(0,1,n)
L = Laplacian(n)
L = L.todense()*h
b=1
k=2/3
time=150
ii=0.01
startpos=[0.5,0.5]
M=20
N=100

for i in ps:
    sol1=SIR_continuous2(b,i,k,time,ii,startpos,M)
    I=sum(sol1.y[2*M*M:])
    plt.plot(sol1.t, I,label=np.round(i,2)) 

plt.title("PDE SIR Model(center) p vs infected people")
plt.ylabel("y")
plt.xlabel("x")
plt.legend()
plt.savefig('PDE(center)_p')

# %%
ps = np.linspace(0,1, 10)



b=5
k=0.2
T=150
ii=0.01
startpos=[0.5,0.5]
q=0.01
N=1000
maxv=-1
index=-1
for i,p in enumerate(ps):
    sol1=SIR_discrete_spatial(N,ii,p,q,T,k,startpos)
    plt.plot(range(T+1), sol1[1],label=np.round(p,2)) 
    if max(sol1[1])>maxv:
        index=i

plt.title("Discrete SIR Model(center) p vs infected people")
plt.ylabel("y")
plt.xlabel("x")
plt.xlim((0,20))
plt.legend()
plt.savefig('Discrte_spatial(center)_p')

# %%
index
# Out:
# 9

# %%
p=0.1
b=5
k=0.2
T=150
ii=0.01
startpos=[0.5,0.5]
q=0.01
N=1000

counts=SIR_discrete_spatial(N,ii,p,q,T,k,startpos)
plt.plot(range(T+1), counts[0], c='b',label='s')    # generate the plot
plt.plot(range(T+1), counts[1], c='r',label='i')
plt.plot(range(T+1), counts[2], c='g',label='r')


plt.title("Discrete SIR Model (b=5, k=0.2)(center)")
plt.ylabel("y")
plt.xlabel("x")
plt.legend()
plt.savefig('D_SIR_S_center')

# %%
p=0.1
b=5
k=0.2
T=150
ii=0.01
startpos=[0,0]
q=0.01
N=1000

counts=SIR_discrete_spatial(N,ii,p,q,T,k,startpos)
plt.plot(range(T+1), counts[0], c='b',label='s')    # generate the plot
plt.plot(range(T+1), counts[1], c='r',label='i')
plt.plot(range(T+1), counts[2], c='g',label='r')


plt.title("Discrete SIR Model (b=5, k=0.2)(corner)")
plt.ylabel("y")
plt.xlabel("x")
plt.legend()
plt.savefig('D_SIR_S_corner')

# %%
p=0.1
b=5
k=0.2
T=150
ii=0.01
startpos=None
q=0.01
N=1000

counts=SIR_discrete_spatial(N,ii,p,q,T,k,startpos)
plt.plot(range(T+1), counts[0], c='b',label='s')    # generate the plot
plt.plot(range(T+1), counts[1], c='r',label='i')
plt.plot(range(T+1), counts[2], c='g',label='r')


plt.title("Discrete SIR Model (b=5, k=0.2)(random)")
plt.ylabel("y")
plt.xlabel("x")
plt.legend()
plt.savefig('D_SIR_S_random')

# %%
n = 20
h=(1/n)**2
x = np.linspace(0,1,n)
L = Laplacian(n)
L = L.todense()*h
b=2
k=0.2
time=150
ii=0.01
startpos=[0.5,0.5]
p=0.1
M=20
N=100

sol1=SIR_continuous2(b,p,k,time,ii,startpos,M,N,L)
S=sum(sol1.y[:M*M])
I=sum(sol1.y[2*M*M:])
R=sum(sol1.y[M*M:2*M*M])
plt.plot(sol1.t, S,label='S')
plt.plot(sol1.t, I,label='I') 
plt.plot(sol1.t, R,label='R') 

plt.title("PDE SIR Model(center)")
plt.ylabel("y")
plt.xlabel("x")
plt.legend()
plt.savefig('PDE(center)_s')
max(I)
# Out:
# 0.6780026041825284

# %%
n = 20
h=(1/n)**2
x = np.linspace(0,1,n)
L = Laplacian(n)
L = L.todense()*h
b=4
k=0.2
time=150
ii=0.01
startpos=[0,0]
p=0.1
M=20
N=100

sol1=SIR_continuous2(b,p,k,time,ii,startpos,M,N,L)
S=sum(sol1.y[:M*M])
I=sum(sol1.y[2*M*M:])
R=sum(sol1.y[M*M:2*M*M])
plt.plot(sol1.t, S,label='S')
plt.plot(sol1.t, I,label='I') 
plt.plot(sol1.t, R,label='R') 

plt.title("PDE SIR Model(corner)")
plt.ylabel("y")
plt.xlabel("x")
plt.legend()
plt.savefig('PDE(corner)_s')
max(I)
# Out:
# 0.8089163728928771

# %%
n = 20
h=(1/n)**2
x = np.linspace(0,1,n)
L = Laplacian(n)
L = L.todense()*h
b=5
k=0.2
time=150
ii=0.01
startpos=None
p=0.1
M=20
N=100

sol1=SIR_continuous2(b,p,k,time,ii,startpos,M,N,L)
S=sum(sol1.y[:M*M])
I=sum(sol1.y[2*M*M:])
R=sum(sol1.y[M*M:2*M*M])
plt.plot(sol1.t, S,label='S')
plt.plot(sol1.t, I,label='I') 
plt.plot(sol1.t, R,label='R') 

plt.title("PDE SIR Model(random)")
plt.ylabel("y")
plt.xlabel("x")
plt.legend()
plt.savefig('PDE(random)_s')
